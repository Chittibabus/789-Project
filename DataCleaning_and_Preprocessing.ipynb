# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\Srivatsava Pusarla\Downloads\chicago-crime-20012019\crimes.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6954967 entries, 0 to 6954966
# Data columns (total 30 columns):
# ID                            int64
# Case Number                   object
# Date                          object
# Block                         object
# IUCR                          object
# Primary Type                  object
# Description                   object
# Location Description          object
# Arrest                        bool
# Domestic                      bool
# Beat                          int64
# District                      float64
# Ward                          float64
# Community Area                float64
# FBI Code                      object
# X Coordinate                  float64
# Y Coordinate                  float64
# Year                          int64
# Updated On                    object
# Latitude                      float64
# Longitude                     float64
# Location                      object
# ...

# %%
df.shape
# Out:
# (6954967, 30)

# %%
df.dropna()
# Out:
#                ID Case Number                    Date  \
# 0        11807717    JC408714  08/26/2019 11:58:00 PM
# 1        11807826    JC408716  08/26/2019 11:57:00 PM
# 2        11807746    JC408370  08/26/2019 11:56:00 PM
# 3        11807718    JC408708  08/26/2019 11:55:00 PM
# 4        11807777    JC408706  08/26/2019 11:45:00 PM
# 5        11807745    JC408749  08/26/2019 11:45:00 PM
# 6        11807728    JC408729  08/26/2019 11:45:00 PM
# 7        11807715    JC408724  08/26/2019 11:45:00 PM
# 8        11807724    JC408762  08/26/2019 11:44:00 PM
# 10       11807727    JC408701  08/26/2019 11:30:00 PM
# 11       11807995    JC408968  08/26/2019 11:30:00 PM
# 12       11807714    JC408732  08/26/2019 11:27:00 PM
# 13       11807738    JC408699  08/26/2019 11:23:00 PM
# 15       11807758    JC408707  08/26/2019 11:08:00 PM
# 16       11807702    JC408710  08/26/2019 11:07:00 PM
# 17       11807705    JC408704  08/26/2019 11:05:00 PM
# ...

# %%
df.to_csv('crimes_clean.csv', sep=',')

# %%
df1 = pd.read_csv(r"C:\Users\Srivatsava Pusarla\Downloads\chicago-crime-20012019\lights.csv")
# Out:
# C:\Users\Srivatsava Pusarla\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (0,1,2,3,4,5,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df1.shape
# Out:
# (296671, 15)

# %%
df1.dropna()
# Out:
#        Creation Date           Status Completion Date Service Request Number  \
# 0         03/20/2014  Completed - Dup      08-04-2017            14-00400272
# 1         08-02-2017        Completed      08-04-2017            17-05118301
# 2         07/21/2013  Completed - Dup      08-04-2017            13-00994280
# 3         08-02-2017  Completed - Dup      08-04-2017            17-05115293
# 4         08-03-2017        Completed      08-04-2017            17-05149048
# 5         09/27/2013  Completed - Dup      08-04-2017            13-01441868
# 6         08-02-2017        Completed      08-04-2017            17-05136485
# 7         08-03-2017        Completed      08-04-2017            17-05143874
# 8         05-12-2014  Completed - Dup      08-04-2017            14-00698486
# 9         08-03-2017        Completed      08-04-2017            17-05149056
# 10        08-02-2017        Completed      08-04-2017            17-05120235
# ...

# %%
df1.shape
# Out:
# (296671, 15)

# %%
df.isnull().sum()/len(df.isnull())
# Out:
# ID                            0.000000e+00
# Case Number                   5.751285e-07
# Date                          0.000000e+00
# Block                         0.000000e+00
# IUCR                          0.000000e+00
# Primary Type                  0.000000e+00
# Description                   0.000000e+00
# Location Description          7.837564e-04
# Arrest                        0.000000e+00
# Domestic                      0.000000e+00
# Beat                          0.000000e+00
# District                      6.757760e-06
# Ward                          8.840099e-02
# Community Area                8.820962e-02
# FBI Code                      0.000000e+00
# X Coordinate                  9.485451e-03
# Y Coordinate                  9.485451e-03
# Year                          0.000000e+00
# Updated On                    0.000000e+00
# Latitude                      9.485451e-03
# Longitude                     9.485451e-03
# Location                      9.485451e-03
# ...

# %%
df1.isnull().sum()/len(df1.isnull())
# Out:
# Creation Date              0.122385
# Status                     0.122385
# Completion Date            0.123450
# Service Request Number     0.122385
# Type of Service Request    0.122385
# Street Address             0.122391
# ZIP Codes                  0.124239
# X Coordinate               0.122931
# Y Coordinate               0.122931
# Ward                       0.122766
# Police District            0.122766
# Community Area             0.122759
# Latitude                   0.122931
# Longitude                  0.122931
# Location                   0.122931
# dtype: float64

# %%
sns.heatmap(df1.isnull(),cbar=False)

# %%
df1.to_csv('lights_outage.csv', sep=',')
